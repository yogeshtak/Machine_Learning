# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("data/breastCancer.csv")

# %%
data.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %% [markdown]
# ### Data Preprocessing

# %%
data['class'].value_counts()
# Out:
# 2    458
# 4    241
# Name: class, dtype: int64

# %%
data.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
data['bare_nucleoli'].value_counts()
# Out:
# 1     402
# 10    132
# 2      30
# 5      30
# 3      28
# 8      21
# 4      19
# ?      16
# 9       9
# 7       8
# 6       4
# Name: bare_nucleoli, dtype: int64

# %%
data[data['bare_nucleoli'] == '?']
# Out:
#           id  clump_thickness  size_uniformity  shape_uniformity  \
# 23   1057013                8                4                 5
# 40   1096800                6                6                 6
# 139  1183246                1                1                 1
# 145  1184840                1                1                 3
# 158  1193683                1                1                 2
# 164  1197510                5                1                 1
# 235  1241232                3                1                 4
# 249   169356                3                1                 1
# 275   432809                3                1                 3
# 292   563649                8                8                 8
# 294   606140                1                1                 1
# 297    61634                5                4                 3
# 315   704168                4                6                 5
# ...

# %%
df = data['bare_nucleoli'].replace('?', np.nan)

# %%
df = data.copy()

# %%
df['bare_nucleoli'] = df['bare_nucleoli'].replace('?',np.nan)

# %%
df.head()
# Out:
#         id  clump_thickness  size_uniformity  shape_uniformity  \
# 0  1000025                5                1                 1
# 1  1002945                5                4                 4
# 2  1015425                3                1                 1
# 3  1016277                6                8                 8
# 4  1017023                4                1                 1
#
#    marginal_adhesion  epithelial_size bare_nucleoli  bland_chromatin  \
# 0                  1                2             1                3
# 1                  5                7            10                3
# 2                  1                2             2                3
# 3                  1                3             4                3
# 4                  3                2             1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# 2                1        1      2
# ...

# %%
df.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
df['bare_nucleoli'] = df['bare_nucleoli'].fillna(df['bare_nucleoli'].median())

# %%
df.dtypes
# Out:
# id                    int64
# clump_thickness       int64
# size_uniformity       int64
# shape_uniformity      int64
# marginal_adhesion     int64
# epithelial_size       int64
# bare_nucleoli        object
# bland_chromatin       int64
# normal_nucleoli       int64
# mitoses               int64
# class                 int64
# dtype: object

# %%
df.isna().sum()
# Out:
# id                   0
# clump_thickness      0
# size_uniformity      0
# shape_uniformity     0
# marginal_adhesion    0
# epithelial_size      0
# bare_nucleoli        0
# bland_chromatin      0
# normal_nucleoli      0
# mitoses              0
# class                0
# dtype: int64

# %%
df['bare_nucleoli'] = df['bare_nucleoli'].apply(int)

# %%
df.dtypes
# Out:
# id                   int64
# clump_thickness      int64
# size_uniformity      int64
# shape_uniformity     int64
# marginal_adhesion    int64
# epithelial_size      int64
# bare_nucleoli        int64
# bland_chromatin      int64
# normal_nucleoli      int64
# mitoses              int64
# class                int64
# dtype: object

# %% [markdown]
# ### EDA
